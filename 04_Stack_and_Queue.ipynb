# %% [markdown]
# #4.1 스택이란?

# %% [markdown]
# ## 스택 알아보기

# %% [markdown]
# * 스택(stack)
# <br> : 데이터를 임시 저장할 때 사용하는 자료구조
# <br> : 입출력 순서 => **후입선출(LIF0)** : 가장 나중에 넣은 데이터를 가장 먼저 꺼낸다.

# %% [markdown]
# 용어 정리
# > push : 스택에 데이터를 넣는 작업
# <br> pop : 스택에서 데이터를 꺼내는 작업
# <br> top : 스택의 윗부분
# <br> bottom : 스택의 아랫부분

# %% [markdown]
# push와 pop하는 과정(예시)
# <br> ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 스택 구현하기

# %% [markdown]
# 스택을 구현하는 프로그램을 만들어보자.
